# %%
import requests
from bs4 import BeautifulSoup

# Function to extract match details
def extract_match_details(html_content):
    try:
        # Parse the HTML with BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Find the match block
        match = soup.find('div', class_='ds-p-0')
        if match is None:
            print("Match block not found")
            return

        for m in match:
            # Extract date and convert it to the desired format
            date_element = match.find('div', class_='ds-text-compact-xs ds-font-bold ds-w-24')
            if date_element is None:
                print("Date element not found")
                return
    
            date_raw = date_element.text.strip()
            date_parts = date_raw.split()  # ['Fri,', '18', 'Apr', "'08"]
            print(f"Date parts: {date_parts}")  # Debug: print date parts
            date = f"{date_parts[1]}/{date_parts[2]}/20{date_parts[3]}".replace("'", '')  # Corrected date format
            print(f"Date: {date}")  # Debug: print date
    
            # Extract venue
            venue_element = match.find('div', class_='ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3')
            if venue_element is None:
                print("Venue element not found")
                return
    
            venue_text = venue_element.text
            print(f"Venue text: {venue_text}")  # Debug: print venue text
            venue = venue_text.split('•')[1].strip() if '•' in venue_text else "Unknown venue"
            print(f"Venue: {venue}")  # Debug: print venue
    
            # Extract teams and scores
            team_scores = match.find_all('div', class_='ci-team-score')
            if len(team_scores) < 2:
                print("Team scores not found")
                return
    
            team1_element = team_scores[0].find('p', class_='ds-text-tight-m ds-font-bold ds-capitalize ds-truncate')
            team1_score_element = team_scores[0].find('strong')
            team2_element = team_scores[1].find('p', class_='ds-text-tight-m ds-font-bold ds-capitalize ds-truncate')
            team2_score_element = team_scores[1].find('strong')
            team2_overs_element = team_scores[1].find('span', class_='ds-text-compact-xs ds-mr-0.5')
    
            if not all([team1_element, team1_score_element, team2_element, team2_score_element, team2_overs_element]):
                print("One or more team elements not found")
                return
    
            team1 = team1_element.text.strip()
            team1_score = team1_score_element.text.strip()
            team2 = team2_element.text.strip()
            team2_score = team2_score_element.text.strip()
            team2_overs = team2_overs_element.text.strip()
    
            print(f"Team 1: {team1}, Score: {team1_score}")  # Debug: print team 1 details
            print(f"Team 2: {team2}, Score: {team2_score}, Overs: {team2_overs}")  # Debug: print team 2 details
    
            # Extract result
            result_element = match.find('p', class_='ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo')
            if result_element is None:
                print("Result element not found")
                return
    
            result = result_element.text.strip()
            print(f"Result: {result}")  # Debug: print result
    
            # Print the extracted information
            print(f"Date: {date}")
            print(f"Venue: {venue}")
            print(f"Team 1: {team1}")
            print(f"Team 1 Score: {team1_score}")
            print(f"Team 2: {team2}")
            print(f"Team 2 Score: {team2_score} {team2_overs}")
            print(f"Result: {result}")
    
    except AttributeError as e:
            print(f"Error extracting data: {e}")
            print("ok")

# Example usage
url = 'https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/match-schedule-fixtures-and-results'  # Replace with the actual URL
response = requests.get(url)

if response.status_code == 200:
    extract_match_details(response.text)
else:
    print("Failed to retrieve the webpage.")
# Out:
# Date parts: ['Fri,', '18', 'Apr', "'08"]
# Date: 18/Apr/2008
# Venue text: 1st match (N) • Bengaluru, Indian Premier League
# Venue: Bengaluru, Indian Premier League
# Team 1: Kolkata Knight Riders, Score: 222/3
# Team 2: Royal Challengers Bangalore, Score: 82, Overs: (15.1/20 ov, T:223)
# Result: KKR won by 140 runs
# Date: 18/Apr/2008
# Venue: Bengaluru, Indian Premier League
# Team 1: Kolkata Knight Riders
# Team 1 Score: 222/3
# Team 2: Royal Challengers Bangalore
# Team 2 Score: 82 (15.1/20 ov, T:223)
# Result: KKR won by 140 runs
# Date parts: ['Fri,', '18', 'Apr', "'08"]
# Date: 18/Apr/2008
# Venue text: 1st match (N) • Bengaluru, Indian Premier League
# Venue: Bengaluru, Indian Premier League
# Team 1: Kolkata Knight Riders, Score: 222/3
# Team 2: Royal Challengers Bangalore, Score: 82, Overs: (15.1/20 ov, T:223)
# Result: KKR won by 140 runs
# Date: 18/Apr/2008
# Venue: Bengaluru, Indian Premier League
# Team 1: Kolkata Knight Riders
# Team 1 Score: 222/3
# ...

# %%
print("IPL")
# Out:
# IPL

# %% [markdown]
# <div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 18 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">1st match (N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">222/3</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(15.1/20 ov, T:223) </span><strong class="">82</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="KKR won by 140 runs"><span>KKR won by 140 runs</span></p></div></div></a><div><div class="ds-px-3 ds-py-2 ds-flex ds-items-center ds-pl-0 ds-pb-0"><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/match-photo" title="Photos" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Photos</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs RCB, 1st match, Indian Premier League","description":"KKR vs RCB","startDate":"2008-04-18T15:30:00+01:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs RCB, 1st match, Indian Premier League","description":"KKR vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-04-18T15:30:00+01:00","endDate":"2008-04-18T01:00:00+01:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div>

# %% [markdown]
# <div class="ds-w-full ds-bg-fill-content-prime ds-overflow-hidden ds-rounded-xl ds-border ds-border-line"><div class="ds-p-0"><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-none ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 18 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">1st match (N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">222/3</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(15.1/20 ov, T:223) </span><strong class="">82</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="KKR won by 140 runs"><span>KKR won by 140 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/match-photo" title="Photos" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Photos</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs RCB, 1st match, Indian Premier League","description":"KKR vs RCB","startDate":"2008-04-18T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs RCB, 1st match, Indian Premier League","description":"KKR vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kolkata-knight-riders-1st-match-335982/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-04-18T14:30:00+00:00","endDate":"2008-04-18T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sat, 19 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-chennai-super-kings-2nd-match-335983/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">2nd match (D/N) </span>•&nbsp;Mohali, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">240/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:241) </span><strong class="">207/4</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 33 runs"><span>CSK won by 33 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-chennai-super-kings-2nd-match-335983/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs KXIP, 2nd match, Indian Premier League","description":"CSK vs Kings XI","startDate":"2008-04-19T11:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs KXIP, 2nd match, Indian Premier League","description":"CSK vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-chennai-super-kings-2nd-match-335983/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-04-19T11:30:00+00:00","endDate":"2008-04-19T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mohali","address":{"@type":"PostalAddress","addressLocality":"Punjab Cricket Association Stadium, Mohali, Chandigarh, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-rajasthan-royals-3rd-match-335984/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">3rd match (N) </span>•&nbsp;Delhi, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">129/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(15.1/20 ov, T:130) </span><strong class="">132/1</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Daredevils won by 9 wickets (with 29 balls remaining)"><span>Daredevils won by 9 wickets (with 29 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-rajasthan-royals-3rd-match-335984/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RR vs DC, 3rd match, Indian Premier League","description":"RR vs Daredevils","startDate":"2008-04-19T15:00:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RR vs DC, 3rd match, Indian Premier League","description":"RR vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-rajasthan-royals-3rd-match-335984/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RR"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-04-19T15:00:00+00:00","endDate":"2008-04-19T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Delhi","address":{"@type":"PostalAddress","addressLocality":"Feroz Shah Kotla, Delhi, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sun, 20 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-deccan-chargers-4th-match-335986/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">4th match (D/N) </span>•&nbsp;Eden Gardens, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">110</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19/20 ov, T:111) </span><strong class="">112/5</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="KKR won by 5 wickets (with 6 balls remaining)"><span>KKR won by 5 wickets (with 6 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-deccan-chargers-4th-match-335986/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs KKR, 4th match, Indian Premier League","description":"Chargers vs KKR","startDate":"2008-04-20T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs KKR, 4th match, Indian Premier League","description":"Chargers vs KKR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-deccan-chargers-4th-match-335986/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"KKR"}],"startDate":"2008-04-20T10:30:00+00:00","endDate":"2008-04-20T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Kolkata","address":{"@type":"PostalAddress","addressLocality":"Eden Gardens, Kolkata, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-royal-challengers-bangalore-5th-match-335985/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">5th match (N) </span>•&nbsp;Wankhede, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">165/6</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.4/20 ov, T:166) </span><strong class="">166/5</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RCB won by 5 wickets (with 2 balls remaining)"><span>RCB won by 5 wickets (with 2 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-royal-challengers-bangalore-5th-match-335985/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"MI vs RCB, 5th match, Indian Premier League","description":"MI vs RCB","startDate":"2008-04-20T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"MI vs RCB, 5th match, Indian Premier League","description":"MI vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-royal-challengers-bangalore-5th-match-335985/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"MI"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-04-20T14:30:00+00:00","endDate":"2008-04-20T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mumbai","address":{"@type":"PostalAddress","addressLocality":"Wankhede Stadium, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Mon, 21 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-kings-xi-punjab-6th-match-335987/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">6th match (N) </span>•&nbsp;Jaipur, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">166/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18.1/20 ov, T:167) </span><strong class="">168/4</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 6 wickets (with 11 balls remaining)"><span>RR won by 6 wickets (with 11 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-kings-xi-punjab-6th-match-335987/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KXIP vs RR, 6th match, Indian Premier League","description":"Kings XI vs RR","startDate":"2008-04-21T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KXIP vs RR, 6th match, Indian Premier League","description":"Kings XI vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-kings-xi-punjab-6th-match-335987/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Kings XI"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-04-21T14:30:00+00:00","endDate":"2008-04-21T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Jaipur","address":{"@type":"PostalAddress","addressLocality":"Sawai Mansingh Stadium, Jaipur, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Tue, 22 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-delhi-daredevils-7th-match-335988/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">7th match (N) </span>•&nbsp;Hyderabad, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">142/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(13/20 ov, T:143) </span><strong class="">143/1</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Daredevils won by 9 wickets (with 42 balls remaining)"><span>Daredevils won by 9 wickets (with 42 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-delhi-daredevils-7th-match-335988/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs DC, 7th match, Indian Premier League","description":"Chargers vs Daredevils","startDate":"2008-04-22T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs DC, 7th match, Indian Premier League","description":"Chargers vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-delhi-daredevils-7th-match-335988/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-04-22T14:30:00+00:00","endDate":"2008-04-22T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Hyderabad","address":{"@type":"PostalAddress","addressLocality":"Rajiv Gandhi International Stadium, Uppal, Hyderabad, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Wed, 23 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-mumbai-indians-8th-match-335989/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">8th match (N) </span>•&nbsp;Chennai, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">208/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:209) </span><strong class="">202/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 6 runs"><span>CSK won by 6 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-mumbai-indians-8th-match-335989/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs MI, 8th match, Indian Premier League","description":"CSK vs MI","startDate":"2008-04-23T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs MI, 8th match, Indian Premier League","description":"CSK vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-mumbai-indians-8th-match-335989/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-04-23T14:30:00+00:00","endDate":"2008-04-23T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Chennai","address":{"@type":"PostalAddress","addressLocality":"MA Chidambaram Stadium, Chepauk, Chennai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Thu, 24 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-rajasthan-royals-9th-match-335990/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">9th match (N) </span>•&nbsp;Hyderabad, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">214/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.5/20 ov, T:215) </span><strong class="">217/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 3 wickets (with 1 ball remaining)"><span>RR won by 3 wickets (with 1 ball remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-rajasthan-royals-9th-match-335990/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs RR, 9th match, Indian Premier League","description":"Chargers vs RR","startDate":"2008-04-24T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs RR, 9th match, Indian Premier League","description":"Chargers vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-rajasthan-royals-9th-match-335990/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-04-24T14:30:00+00:00","endDate":"2008-04-24T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Hyderabad","address":{"@type":"PostalAddress","addressLocality":"Rajiv Gandhi International Stadium, Uppal, Hyderabad, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 25 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-mumbai-indians-10th-match-335991/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">10th match (N) </span>•&nbsp;Mohali, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">182</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:183) </span><strong class="">116/9</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 66 runs"><span>Kings XI won by 66 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-mumbai-indians-10th-match-335991/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KXIP vs MI, 10th match, Indian Premier League","description":"Kings XI vs MI","startDate":"2008-04-25T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KXIP vs MI, 10th match, Indian Premier League","description":"Kings XI vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-mumbai-indians-10th-match-335991/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Kings XI"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-04-25T14:30:00+00:00","endDate":"2008-04-25T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mohali","address":{"@type":"PostalAddress","addressLocality":"Punjab Cricket Association Stadium, Mohali, Chandigarh, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sat, 26 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kolkata-knight-riders-11th-match-335993/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">11th match (D/N) </span>•&nbsp;Chennai, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">147/9</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(17/20 ov, T:148) </span><strong class="">152/1</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 9 wickets (with 18 balls remaining)"><span>CSK won by 9 wickets (with 18 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kolkata-knight-riders-11th-match-335993/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs CSK, 11th match, Indian Premier League","description":"KKR vs CSK","startDate":"2008-04-26T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs CSK, 11th match, Indian Premier League","description":"KKR vs CSK","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kolkata-knight-riders-11th-match-335993/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"CSK"}],"startDate":"2008-04-26T10:30:00+00:00","endDate":"2008-04-26T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Chennai","address":{"@type":"PostalAddress","addressLocality":"MA Chidambaram Stadium, Chepauk, Chennai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-rajasthan-royals-12th-match-335992/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">12th match (N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">135/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(17.1/20 ov, T:136) </span><strong class="">138/3</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 7 wickets (with 17 balls remaining)"><span>RR won by 7 wickets (with 17 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-rajasthan-royals-12th-match-335992/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RCB vs RR, 12th match, Indian Premier League","description":"RCB vs RR","startDate":"2008-04-26T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RCB vs RR, 12th match, Indian Premier League","description":"RCB vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-rajasthan-royals-12th-match-335992/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RCB"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-04-26T14:30:00+00:00","endDate":"2008-04-26T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sun, 27 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-delhi-daredevils-13th-match-335995/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">13th match (D/N) </span>•&nbsp;Mohali, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">158/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.3/20 ov, T:159) </span><strong class="">162/6</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 4 wickets (with 3 balls remaining)"><span>Kings XI won by 4 wickets (with 3 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-delhi-daredevils-13th-match-335995/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DC vs KXIP, 13th match, Indian Premier League","description":"Daredevils vs Kings XI","startDate":"2008-04-27T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DC vs KXIP, 13th match, Indian Premier League","description":"Daredevils vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-delhi-daredevils-13th-match-335995/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Daredevils"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-04-27T10:30:00+00:00","endDate":"2008-04-27T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mohali","address":{"@type":"PostalAddress","addressLocality":"Punjab Cricket Association Stadium, Mohali, Chandigarh, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-deccan-chargers-14th-match-335994/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">14th match (N) </span>•&nbsp;DY Patil, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">154/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(12/20 ov, T:155) </span><strong class="">155/0</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Chargers won by 10 wickets (with 48 balls remaining)"><span>Chargers won by 10 wickets (with 48 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-deccan-chargers-14th-match-335994/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"MI vs DCH, 14th match, Indian Premier League","description":"MI vs Chargers","startDate":"2008-04-27T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"MI vs DCH, 14th match, Indian Premier League","description":"MI vs Chargers","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-deccan-chargers-14th-match-335994/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"MI"},{"@type":"SportsTeam","name":"Chargers"}],"startDate":"2008-04-27T14:30:00+00:00","endDate":"2008-04-27T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Navi Mumbai","address":{"@type":"PostalAddress","addressLocality":"Dr DY Patil Sports Academy, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Mon, 28 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-chennai-super-kings-15th-match-335996/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">15th match (N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">178/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.4/20 ov, T:179) </span><strong class="">165</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 13 runs"><span>CSK won by 13 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-chennai-super-kings-15th-match-335996/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs RCB, 15th match, Indian Premier League","description":"CSK vs RCB","startDate":"2008-04-28T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs RCB, 15th match, Indian Premier League","description":"CSK vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-chennai-super-kings-15th-match-335996/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-04-28T14:30:00+00:00","endDate":"2008-04-28T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Tue, 29 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-mumbai-indians-16th-match-335997/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">16th match (N) </span>•&nbsp;Eden Gardens, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">137/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18.4/20 ov, T:138) </span><strong class="">138/3</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="MI won by 7 wickets (with 8 balls remaining)"><span>MI won by 7 wickets (with 8 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-mumbai-indians-16th-match-335997/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs MI, 16th match, Indian Premier League","description":"KKR vs MI","startDate":"2008-04-29T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs MI, 16th match, Indian Premier League","description":"KKR vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-mumbai-indians-16th-match-335997/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-04-29T14:30:00+00:00","endDate":"2008-04-29T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Kolkata","address":{"@type":"PostalAddress","addressLocality":"Eden Gardens, Kolkata, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Wed, 30 Apr '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-royal-challengers-bangalore-17th-match-335998/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">17th match (N) </span>•&nbsp;Delhi, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">191/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:192) </span><strong class="">181/5</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Daredevils won by 10 runs"><span>Daredevils won by 10 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-royal-challengers-bangalore-17th-match-335998/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DC vs RCB, 17th match, Indian Premier League","description":"Daredevils vs RCB","startDate":"2008-04-30T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DC vs RCB, 17th match, Indian Premier League","description":"Daredevils vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-royal-challengers-bangalore-17th-match-335998/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Daredevils"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-04-30T14:30:00+00:00","endDate":"2008-04-30T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Delhi","address":{"@type":"PostalAddress","addressLocality":"Feroz Shah Kotla, Delhi, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Thu, 01 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-kolkata-knight-riders-18th-match-336000/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">18th match (D/N) </span>•&nbsp;Jaipur, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">196/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.1/20 ov, T:197) </span><strong class="">151</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 45 runs"><span>RR won by 45 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-kolkata-knight-riders-18th-match-336000/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RR vs KKR, 18th match, Indian Premier League","description":"RR vs KKR","startDate":"2008-05-01T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RR vs KKR, 18th match, Indian Premier League","description":"RR vs KKR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-kolkata-knight-riders-18th-match-336000/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RR"},{"@type":"SportsTeam","name":"KKR"}],"startDate":"2008-05-01T10:30:00+00:00","endDate":"2008-05-01T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Jaipur","address":{"@type":"PostalAddress","addressLocality":"Sawai Mansingh Stadium, Jaipur, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-kings-xi-punjab-19th-match-335999/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">19th match (N) </span>•&nbsp;Hyderabad, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">164/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18.5/20 ov, T:165) </span><strong class="">167/3</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 7 wickets (with 7 balls remaining)"><span>Kings XI won by 7 wickets (with 7 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-kings-xi-punjab-19th-match-335999/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs KXIP, 19th match, Indian Premier League","description":"Chargers vs Kings XI","startDate":"2008-05-01T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs KXIP, 19th match, Indian Premier League","description":"Chargers vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-kings-xi-punjab-19th-match-335999/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-05-01T14:30:00+00:00","endDate":"2008-05-01T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Hyderabad","address":{"@type":"PostalAddress","addressLocality":"Rajiv Gandhi International Stadium, Uppal, Hyderabad, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 02 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-delhi-daredevils-20th-match-336001/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">20th match (N) </span>•&nbsp;Chennai, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">169/6</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19/20 ov, T:170) </span><strong class="">172/2</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Daredevils won by 8 wickets (with 6 balls remaining)"><span>Daredevils won by 8 wickets (with 6 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-delhi-daredevils-20th-match-336001/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs DC, 20th match, Indian Premier League","description":"CSK vs Daredevils","startDate":"2008-05-02T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs DC, 20th match, Indian Premier League","description":"CSK vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-delhi-daredevils-20th-match-336001/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-05-02T14:30:00+00:00","endDate":"2008-05-02T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Chennai","address":{"@type":"PostalAddress","addressLocality":"MA Chidambaram Stadium, Chepauk, Chennai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sat, 03 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-deccan-chargers-21st-match-336034/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">21st match (D/N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">156/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:157) </span><strong class="">153/6</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RCB won by 3 runs"><span>RCB won by 3 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-deccan-chargers-21st-match-336034/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RCB vs DCH, 21st match, Indian Premier League","description":"RCB vs Chargers","startDate":"2008-05-03T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RCB vs DCH, 21st match, Indian Premier League","description":"RCB vs Chargers","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-deccan-chargers-21st-match-336034/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RCB"},{"@type":"SportsTeam","name":"Chargers"}],"startDate":"2008-05-03T10:30:00+00:00","endDate":"2008-05-03T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-kolkata-knight-riders-22nd-match-336003/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">22nd match (N) </span>•&nbsp;Mohali, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">178/6</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:179) </span><strong class="">169/6</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 9 runs"><span>Kings XI won by 9 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-kolkata-knight-riders-22nd-match-336003/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KXIP vs KKR, 22nd match, Indian Premier League","description":"Kings XI vs KKR","startDate":"2008-05-03T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KXIP vs KKR, 22nd match, Indian Premier League","description":"Kings XI vs KKR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-kolkata-knight-riders-22nd-match-336003/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Kings XI"},{"@type":"SportsTeam","name":"KKR"}],"startDate":"2008-05-03T14:30:00+00:00","endDate":"2008-05-03T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mohali","address":{"@type":"PostalAddress","addressLocality":"Punjab Cricket Association Stadium, Mohali, Chandigarh, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sun, 04 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-delhi-daredevils-23rd-match-336004/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">23rd match (D/N) </span>•&nbsp;DY Patil, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">162/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18.5/20 ov, T:163) </span><strong class="">133</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="MI won by 29 runs"><span>MI won by 29 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-delhi-daredevils-23rd-match-336004/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"MI vs DC, 23rd match, Indian Premier League","description":"MI vs Daredevils","startDate":"2008-05-04T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"MI vs DC, 23rd match, Indian Premier League","description":"MI vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-delhi-daredevils-23rd-match-336004/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"MI"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-05-04T10:30:00+00:00","endDate":"2008-05-04T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Navi Mumbai","address":{"@type":"PostalAddress","addressLocality":"Dr DY Patil Sports Academy, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-chennai-super-kings-24th-match-336005/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">24th match (N) </span>•&nbsp;Jaipur, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">109</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(14.2/20 ov, T:110) </span><strong class="">110/2</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 8 wickets (with 34 balls remaining)"><span>RR won by 8 wickets (with 34 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-chennai-super-kings-24th-match-336005/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs RR, 24th match, Indian Premier League","description":"CSK vs RR","startDate":"2008-05-04T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs RR, 24th match, Indian Premier League","description":"CSK vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-chennai-super-kings-24th-match-336005/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-05-04T14:30:00+00:00","endDate":"2008-05-04T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Jaipur","address":{"@type":"PostalAddress","addressLocality":"Sawai Mansingh Stadium, Jaipur, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Mon, 05 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kings-xi-punjab-25th-match-336006/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">25th match (N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">126</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18.2/20 ov, T:127) </span><strong class="">127/4</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 6 wickets (with 10 balls remaining)"><span>Kings XI won by 6 wickets (with 10 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kings-xi-punjab-25th-match-336006/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RCB vs KXIP, 25th match, Indian Premier League","description":"RCB vs Kings XI","startDate":"2008-05-05T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RCB vs KXIP, 25th match, Indian Premier League","description":"RCB vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-kings-xi-punjab-25th-match-336006/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RCB"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-05-05T14:30:00+00:00","endDate":"2008-05-05T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Tue, 06 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-deccan-chargers-26th-match-336007/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">26th match (N) </span>•&nbsp;Chennai, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">144/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18/20 ov, T:145) </span><strong class="">148/3</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Chargers won by 7 wickets (with 12 balls remaining)"><span>Chargers won by 7 wickets (with 12 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-deccan-chargers-26th-match-336007/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs DCH, 26th match, Indian Premier League","description":"CSK vs Chargers","startDate":"2008-05-06T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs DCH, 26th match, Indian Premier League","description":"CSK vs Chargers","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-deccan-chargers-26th-match-336007/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"Chargers"}],"startDate":"2008-05-06T14:30:00+00:00","endDate":"2008-05-06T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Chennai","address":{"@type":"PostalAddress","addressLocality":"MA Chidambaram Stadium, Chepauk, Chennai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Wed, 07 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-rajasthan-royals-27th-match-336008/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">27th match (N) </span>•&nbsp;DY Patil, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">103</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(15.1/20 ov, T:104) </span><strong class="">104/3</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="MI won by 7 wickets (with 29 balls remaining)"><span>MI won by 7 wickets (with 29 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-rajasthan-royals-27th-match-336008/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RR vs MI, 27th match, Indian Premier League","description":"RR vs MI","startDate":"2008-05-07T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RR vs MI, 27th match, Indian Premier League","description":"RR vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-rajasthan-royals-27th-match-336008/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RR"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-05-07T14:30:00+00:00","endDate":"2008-05-07T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Navi Mumbai","address":{"@type":"PostalAddress","addressLocality":"Dr DY Patil Sports Academy, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Thu, 08 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-chennai-super-kings-28th-match-336009/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">28th match (D/N) </span>•&nbsp;Delhi, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">187/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:188) </span><strong class="">188/6</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 4 wickets (with 0 balls remaining)"><span>CSK won by 4 wickets (with 0 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-chennai-super-kings-28th-match-336009/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DC vs CSK, 28th match, Indian Premier League","description":"Daredevils vs CSK","startDate":"2008-05-08T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DC vs CSK, 28th match, Indian Premier League","description":"Daredevils vs CSK","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-chennai-super-kings-28th-match-336009/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Daredevils"},{"@type":"SportsTeam","name":"CSK"}],"startDate":"2008-05-08T10:30:00+00:00","endDate":"2008-05-08T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Delhi","address":{"@type":"PostalAddress","addressLocality":"Feroz Shah Kotla, Delhi, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-royal-challengers-bangalore-29th-match-336010/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">29th match (N) </span>•&nbsp;Eden Gardens, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(16/16 ov) </span><strong class="">129/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(16/16 ov, T:130) </span><strong class="">124/4</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="KKR won by 5 runs"><span>KKR won by 5 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-royal-challengers-bangalore-29th-match-336010/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs RCB, 29th match, Indian Premier League","description":"KKR vs RCB","startDate":"2008-05-08T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs RCB, 29th match, Indian Premier League","description":"KKR vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-royal-challengers-bangalore-29th-match-336010/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-05-08T14:30:00+00:00","endDate":"2008-05-08T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Kolkata","address":{"@type":"PostalAddress","addressLocality":"Eden Gardens, Kolkata, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 09 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-deccan-chargers-30th-match-336011/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">30th match (N) </span>•&nbsp;Jaipur, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">140/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(16/20 ov, T:141) </span><strong class="">141/2</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 8 wickets (with 24 balls remaining)"><span>RR won by 8 wickets (with 24 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-deccan-chargers-30th-match-336011/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs RR, 30th match, Indian Premier League","description":"Chargers vs RR","startDate":"2008-05-09T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs RR, 30th match, Indian Premier League","description":"Chargers vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-deccan-chargers-30th-match-336011/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-05-09T14:30:00+00:00","endDate":"2008-05-09T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Jaipur","address":{"@type":"PostalAddress","addressLocality":"Sawai Mansingh Stadium, Jaipur, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sat, 10 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kings-xi-punjab-31st-match-336013/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">31st match (N) </span>•&nbsp;Chennai, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">181/4</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:182) </span><strong class="">163/9</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 18 runs"><span>CSK won by 18 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kings-xi-punjab-31st-match-336013/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs KXIP, 31st match, Indian Premier League","description":"CSK vs Kings XI","startDate":"2008-05-10T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs KXIP, 31st match, Indian Premier League","description":"CSK vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kings-xi-punjab-31st-match-336013/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-05-10T14:30:00+00:00","endDate":"2008-05-10T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Chennai","address":{"@type":"PostalAddress","addressLocality":"MA Chidambaram Stadium, Chepauk, Chennai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sun, 11 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-kolkata-knight-riders-32nd-match-336014/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">32nd match (D/N) </span>•&nbsp;Hyderabad, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">204/4</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:205) </span><strong class="">181/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="KKR won by 23 runs"><span>KKR won by 23 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-kolkata-knight-riders-32nd-match-336014/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs DCH, 32nd match, Indian Premier League","description":"KKR vs Chargers","startDate":"2008-05-11T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs DCH, 32nd match, Indian Premier League","description":"KKR vs Chargers","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-kolkata-knight-riders-32nd-match-336014/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"Chargers"}],"startDate":"2008-05-11T10:30:00+00:00","endDate":"2008-05-11T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Hyderabad","address":{"@type":"PostalAddress","addressLocality":"Rajiv Gandhi International Stadium, Uppal, Hyderabad, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-delhi-daredevils-33rd-match-336015/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">33rd match (N) </span>•&nbsp;Jaipur, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">156/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.1/20 ov, T:157) </span><strong class="">159/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 3 wickets (with 5 balls remaining)"><span>RR won by 3 wickets (with 5 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-delhi-daredevils-33rd-match-336015/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DC vs RR, 33rd match, Indian Premier League","description":"Daredevils vs RR","startDate":"2008-05-11T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DC vs RR, 33rd match, Indian Premier League","description":"Daredevils vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-delhi-daredevils-33rd-match-336015/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Daredevils"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-05-11T14:30:00+00:00","endDate":"2008-05-11T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Jaipur","address":{"@type":"PostalAddress","addressLocality":"Sawai Mansingh Stadium, Jaipur, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Mon, 12 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-royal-challengers-bangalore-34th-match-336016/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">34th match (N) </span>•&nbsp;Mohali, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">143/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(15.4/20 ov, T:144) </span><strong class="">144/1</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 9 wickets (with 26 balls remaining)"><span>Kings XI won by 9 wickets (with 26 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-royal-challengers-bangalore-34th-match-336016/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RCB vs KXIP, 34th match, Indian Premier League","description":"RCB vs Kings XI","startDate":"2008-05-12T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RCB vs KXIP, 34th match, Indian Premier League","description":"RCB vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-royal-challengers-bangalore-34th-match-336016/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RCB"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-05-12T14:30:00+00:00","endDate":"2008-05-12T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mohali","address":{"@type":"PostalAddress","addressLocality":"Punjab Cricket Association Stadium, Mohali, Chandigarh, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Tue, 13 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-delhi-daredevils-35th-match-336017/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">35th match (N) </span>•&nbsp;Eden Gardens, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">133/6</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(17.5/20 ov, T:134) </span><strong class="">110</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="KKR won by 23 runs"><span>KKR won by 23 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-delhi-daredevils-35th-match-336017/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs DC, 35th match, Indian Premier League","description":"KKR vs Daredevils","startDate":"2008-05-13T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs DC, 35th match, Indian Premier League","description":"KKR vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-delhi-daredevils-35th-match-336017/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-05-13T14:30:00+00:00","endDate":"2008-05-13T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Kolkata","address":{"@type":"PostalAddress","addressLocality":"Eden Gardens, Kolkata, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Wed, 14 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-chennai-super-kings-36th-match-336018/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">36th match (N) </span>•&nbsp;Wankhede, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">156/6</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(13.5/20 ov, T:157) </span><strong class="">158/1</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="MI won by 9 wickets (with 37 balls remaining)"><span>MI won by 9 wickets (with 37 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-chennai-super-kings-36th-match-336018/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs MI, 36th match, Indian Premier League","description":"CSK vs MI","startDate":"2008-05-14T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs MI, 36th match, Indian Premier League","description":"CSK vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-chennai-super-kings-36th-match-336018/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-05-14T14:30:00+00:00","endDate":"2008-05-14T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mumbai","address":{"@type":"PostalAddress","addressLocality":"Wankhede Stadium, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Thu, 15 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-deccan-chargers-37th-match-336020/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">37th match (N) </span>•&nbsp;Delhi, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">194/4</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:195) </span><strong class="">182/9</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Daredevils won by 12 runs"><span>Daredevils won by 12 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-deccan-chargers-37th-match-336020/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DC vs DCH, 37th match, Indian Premier League","description":"Daredevils vs Chargers","startDate":"2008-05-15T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DC vs DCH, 37th match, Indian Premier League","description":"Daredevils vs Chargers","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-deccan-chargers-37th-match-336020/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Daredevils"},{"@type":"SportsTeam","name":"Chargers"}],"startDate":"2008-05-15T14:30:00+00:00","endDate":"2008-05-15T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Delhi","address":{"@type":"PostalAddress","addressLocality":"Feroz Shah Kotla, Delhi, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 16 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-kolkata-knight-riders-38th-match-336021/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">38th match (N) </span>•&nbsp;Wankhede, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">67</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(5.3/20 ov, T:68) </span><strong class="">68/2</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="MI won by 8 wickets (with 87 balls remaining)"><span>MI won by 8 wickets (with 87 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-kolkata-knight-riders-38th-match-336021/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs MI, 38th match, Indian Premier League","description":"KKR vs MI","startDate":"2008-05-16T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs MI, 38th match, Indian Premier League","description":"KKR vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-kolkata-knight-riders-38th-match-336021/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-05-16T14:30:00+00:00","endDate":"2008-05-16T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mumbai","address":{"@type":"PostalAddress","addressLocality":"Wankhede Stadium, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sat, 17 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-royal-challengers-bangalore-39th-match-336023/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">39th match (D/N) </span>•&nbsp;Jaipur, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">197/1</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://wassets.hscicdn.com/static/images/lazyimage-transparent.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:198) </span><strong class="">132/9</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 65 runs"><span>RR won by 65 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-royal-challengers-bangalore-39th-match-336023/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RR vs RCB, 39th match, Indian Premier League","description":"RR vs RCB","startDate":"2008-05-17T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RR vs RCB, 39th match, Indian Premier League","description":"RR vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-royal-challengers-bangalore-39th-match-336023/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RR"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-05-17T10:30:00+00:00","endDate":"2008-05-17T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Jaipur","address":{"@type":"PostalAddress","addressLocality":"Sawai Mansingh Stadium, Jaipur, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-kings-xi-punjab-40th-match-336022/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">40th match (N) </span>•&nbsp;Delhi, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(11/11 ov) </span><strong class="">118/4</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(8/8 ov, T:89) </span><strong class="">94/3</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 6 runs (D/L method)"><span>Kings XI won by 6 runs (D/L method)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-kings-xi-punjab-40th-match-336022/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DC vs KXIP, 40th match, Indian Premier League","description":"Daredevils vs Kings XI","startDate":"2008-05-17T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DC vs KXIP, 40th match, Indian Premier League","description":"Daredevils vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-kings-xi-punjab-40th-match-336022/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Daredevils"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-05-17T14:30:00+00:00","endDate":"2008-05-17T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Delhi","address":{"@type":"PostalAddress","addressLocality":"Feroz Shah Kotla, Delhi, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sun, 18 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-chennai-super-kings-41st-match-336025/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">41st match (D/N) </span>•&nbsp;Eden Gardens, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">149/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(8/8 ov, T:53) </span><strong class="">55/0</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 3 runs (D/L method)"><span>CSK won by 3 runs (D/L method)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-chennai-super-kings-41st-match-336025/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs CSK, 41st match, Indian Premier League","description":"KKR vs CSK","startDate":"2008-05-18T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs CSK, 41st match, Indian Premier League","description":"KKR vs CSK","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-chennai-super-kings-41st-match-336025/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"CSK"}],"startDate":"2008-05-18T10:30:00+00:00","endDate":"2008-05-18T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Kolkata","address":{"@type":"PostalAddress","addressLocality":"Eden Gardens, Kolkata, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-mumbai-indians-42nd-match-336024/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">42nd match (N) </span>•&nbsp;Hyderabad, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">178/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:179) </span><strong class="">153/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="MI won by 25 runs"><span>MI won by 25 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-mumbai-indians-42nd-match-336024/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"MI vs DCH, 42nd match, Indian Premier League","description":"MI vs Chargers","startDate":"2008-05-18T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"MI vs DCH, 42nd match, Indian Premier League","description":"MI vs Chargers","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-mumbai-indians-42nd-match-336024/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"MI"},{"@type":"SportsTeam","name":"Chargers"}],"startDate":"2008-05-18T14:30:00+00:00","endDate":"2008-05-18T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Hyderabad","address":{"@type":"PostalAddress","addressLocality":"Rajiv Gandhi International Stadium, Uppal, Hyderabad, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Mon, 19 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-delhi-daredevils-43rd-match-336026/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">43rd match (N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">154/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18.2/20 ov, T:155) </span><strong class="">158/5</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Daredevils won by 5 wickets (with 10 balls remaining)"><span>Daredevils won by 5 wickets (with 10 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-delhi-daredevils-43rd-match-336026/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RCB vs DC, 43rd match, Indian Premier League","description":"RCB vs Daredevils","startDate":"2008-05-19T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RCB vs DC, 43rd match, Indian Premier League","description":"RCB vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-delhi-daredevils-43rd-match-336026/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RCB"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-05-19T14:30:00+00:00","endDate":"2008-05-19T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Tue, 20 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-rajasthan-royals-44th-match-336027/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">44th match (N) </span>•&nbsp;Eden Gardens, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">147/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(16.3/20 ov, T:148) </span><strong class="">150/4</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 6 wickets (with 21 balls remaining)"><span>RR won by 6 wickets (with 21 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-rajasthan-royals-44th-match-336027/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KKR vs RR, 44th match, Indian Premier League","description":"KKR vs RR","startDate":"2008-05-20T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KKR vs RR, 44th match, Indian Premier League","description":"KKR vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-rajasthan-royals-44th-match-336027/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"KKR"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-05-20T14:30:00+00:00","endDate":"2008-05-20T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Kolkata","address":{"@type":"PostalAddress","addressLocality":"Eden Gardens, Kolkata, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Wed, 21 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-kings-xi-punjab-45th-match-336028/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">45th match (D/N) </span>•&nbsp;Wankhede, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">189/4</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:190) </span><strong class="">188</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 1 run"><span>Kings XI won by 1 run</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-kings-xi-punjab-45th-match-336028/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KXIP vs MI, 45th match, Indian Premier League","description":"Kings XI vs MI","startDate":"2008-05-21T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KXIP vs MI, 45th match, Indian Premier League","description":"Kings XI vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/mumbai-indians-vs-kings-xi-punjab-45th-match-336028/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Kings XI"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-05-21T10:30:00+00:00","endDate":"2008-05-21T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mumbai","address":{"@type":"PostalAddress","addressLocality":"Wankhede Stadium, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-royal-challengers-bangalore-46th-match-336029/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">46th match (N) </span>•&nbsp;Chennai, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">126/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:127) </span><strong class="">112/8</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RCB won by 14 runs"><span>RCB won by 14 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-royal-challengers-bangalore-46th-match-336029/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RCB vs CSK, 46th match, Indian Premier League","description":"RCB vs CSK","startDate":"2008-05-21T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RCB vs CSK, 46th match, Indian Premier League","description":"RCB vs CSK","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-royal-challengers-bangalore-46th-match-336029/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RCB"},{"@type":"SportsTeam","name":"CSK"}],"startDate":"2008-05-21T14:30:00+00:00","endDate":"2008-05-21T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Chennai","address":{"@type":"PostalAddress","addressLocality":"MA Chidambaram Stadium, Chepauk, Chennai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Thu, 22 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-kolkata-knight-riders-47th-match-336030/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">ABANDONED</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">47th match (N) </span>•&nbsp;Delhi, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Match abandoned without a ball bowled"><span>Match abandoned without a ball bowled</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-kolkata-knight-riders-47th-match-336030/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DC vs KKR, 47th match, Indian Premier League","description":"Daredevils vs KKR","startDate":"2008-05-22T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DC vs KKR, 47th match, Indian Premier League","description":"Daredevils vs KKR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-kolkata-knight-riders-47th-match-336030/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Daredevils"},{"@type":"SportsTeam","name":"KKR"}],"startDate":"2008-05-22T14:30:00+00:00","endDate":"2008-05-22T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"ABANDONED","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Delhi","address":{"@type":"PostalAddress","addressLocality":"Feroz Shah Kotla, Delhi, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 23 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-deccan-chargers-48th-match-336031/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">48th match (N) </span>•&nbsp;Mohali, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">175/4</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.3/20 ov, T:176) </span><strong class="">178/4</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 6 wickets (with 3 balls remaining)"><span>Kings XI won by 6 wickets (with 3 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-deccan-chargers-48th-match-336031/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs KXIP, 48th match, Indian Premier League","description":"Chargers vs Kings XI","startDate":"2008-05-23T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs KXIP, 48th match, Indian Premier League","description":"Chargers vs Kings XI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-deccan-chargers-48th-match-336031/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"Kings XI"}],"startDate":"2008-05-23T14:30:00+00:00","endDate":"2008-05-23T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mohali","address":{"@type":"PostalAddress","addressLocality":"Punjab Cricket Association Stadium, Mohali, Chandigarh, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sat, 24 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-rajasthan-royals-49th-match-336033/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">49th match (D/N) </span>•&nbsp;Chennai, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">211/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:212) </span><strong class="">201/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 10 runs"><span>RR won by 10 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-rajasthan-royals-49th-match-336033/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RR vs CSK, 49th match, Indian Premier League","description":"RR vs CSK","startDate":"2008-05-24T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RR vs CSK, 49th match, Indian Premier League","description":"RR vs CSK","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-rajasthan-royals-49th-match-336033/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RR"},{"@type":"SportsTeam","name":"CSK"}],"startDate":"2008-05-24T10:30:00+00:00","endDate":"2008-05-24T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Chennai","address":{"@type":"PostalAddress","addressLocality":"MA Chidambaram Stadium, Chepauk, Chennai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-mumbai-indians-50th-match-336032/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">50th match (N) </span>•&nbsp;Delhi, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">176/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.5/20 ov, T:177) </span><strong class="">179/5</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Daredevils won by 5 wickets (with 1 ball remaining)"><span>Daredevils won by 5 wickets (with 1 ball remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-mumbai-indians-50th-match-336032/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"MI vs DC, 50th match, Indian Premier League","description":"MI vs Daredevils","startDate":"2008-05-24T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"MI vs DC, 50th match, Indian Premier League","description":"MI vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-mumbai-indians-50th-match-336032/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"MI"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-05-24T14:30:00+00:00","endDate":"2008-05-24T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Delhi","address":{"@type":"PostalAddress","addressLocality":"Feroz Shah Kotla, Delhi, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sun, 25 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-royal-challengers-bangalore-51st-match-336002/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">51st match (D/N) </span>•&nbsp;Hyderabad, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">165</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19/20 ov, T:166) </span><strong class="">171/5</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RCB won by 5 wickets (with 6 balls remaining)"><span>RCB won by 5 wickets (with 6 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-royal-challengers-bangalore-51st-match-336002/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs RCB, 51st match, Indian Premier League","description":"Chargers vs RCB","startDate":"2008-05-25T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs RCB, 51st match, Indian Premier League","description":"Chargers vs RCB","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-royal-challengers-bangalore-51st-match-336002/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"RCB"}],"startDate":"2008-05-25T10:30:00+00:00","endDate":"2008-05-25T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Hyderabad","address":{"@type":"PostalAddress","addressLocality":"Rajiv Gandhi International Stadium, Uppal, Hyderabad, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-kings-xi-punjab-52nd-match-336035/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">52nd match (N) </span>•&nbsp;Eden Gardens, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">174/6</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kolkata Knight Riders"><img width="20" height="20" alt="Kolkata Knight Riders Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313419.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kolkata Knight Riders</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.4/20 ov, T:175) </span><strong class="">175/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="KKR won by 3 wickets (with 2 balls remaining)"><span>KKR won by 3 wickets (with 2 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-kings-xi-punjab-52nd-match-336035/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KXIP vs KKR, 52nd match, Indian Premier League","description":"Kings XI vs KKR","startDate":"2008-05-25T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KXIP vs KKR, 52nd match, Indian Premier League","description":"Kings XI vs KKR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kolkata-knight-riders-vs-kings-xi-punjab-52nd-match-336035/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Kings XI"},{"@type":"SportsTeam","name":"KKR"}],"startDate":"2008-05-25T14:30:00+00:00","endDate":"2008-05-25T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Kolkata","address":{"@type":"PostalAddress","addressLocality":"Eden Gardens, Kolkata, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Mon, 26 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-mumbai-indians-53rd-match-336036/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">53rd match (N) </span>•&nbsp;Jaipur, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">145/7</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:146) </span><strong class="">146/5</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 5 wickets (with 0 balls remaining)"><span>RR won by 5 wickets (with 0 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-mumbai-indians-53rd-match-336036/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"MI vs RR, 53rd match, Indian Premier League","description":"MI vs RR","startDate":"2008-05-26T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"MI vs RR, 53rd match, Indian Premier League","description":"MI vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/rajasthan-royals-vs-mumbai-indians-53rd-match-336036/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"MI"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-05-26T14:30:00+00:00","endDate":"2008-05-26T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Jaipur","address":{"@type":"PostalAddress","addressLocality":"Sawai Mansingh Stadium, Jaipur, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Tue, 27 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-chennai-super-kings-54th-match-336037/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">54th match (N) </span>•&nbsp;Hyderabad, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Deccan Chargers"><img width="20" height="20" alt="Deccan Chargers Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/321600/321684.jpg" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Deccan Chargers</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">147/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(19.2/20 ov, T:148) </span><strong class="">148/3</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 7 wickets (with 4 balls remaining)"><span>CSK won by 7 wickets (with 4 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-chennai-super-kings-54th-match-336037/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"DCH vs CSK, 54th match, Indian Premier League","description":"Chargers vs CSK","startDate":"2008-05-27T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"DCH vs CSK, 54th match, Indian Premier League","description":"Chargers vs CSK","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/deccan-chargers-vs-chennai-super-kings-54th-match-336037/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Chargers"},{"@type":"SportsTeam","name":"CSK"}],"startDate":"2008-05-27T14:30:00+00:00","endDate":"2008-05-27T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Hyderabad","address":{"@type":"PostalAddress","addressLocality":"Rajiv Gandhi International Stadium, Uppal, Hyderabad, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Wed, 28 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-mumbai-indians-55th-match-336012/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">55th match (D/N) </span>•&nbsp;Bengaluru, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Royal Challengers Bangalore"><img width="20" height="20" alt="Royal Challengers Bangalore Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/378000/378049.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Royal Challengers Bangalore</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(18/18 ov) </span><strong class="">122/9</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Mumbai Indians"><img width="20" height="20" alt="Mumbai Indians Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/344000/344062.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Mumbai Indians</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(16/18 ov, T:123) </span><strong class="">126/1</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="MI won by 9 wickets (with 12 balls remaining)"><span>MI won by 9 wickets (with 12 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-mumbai-indians-55th-match-336012/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RCB vs MI, 55th match, Indian Premier League","description":"RCB vs MI","startDate":"2008-05-28T10:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RCB vs MI, 55th match, Indian Premier League","description":"RCB vs MI","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/royal-challengers-bangalore-vs-mumbai-indians-55th-match-336012/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RCB"},{"@type":"SportsTeam","name":"MI"}],"startDate":"2008-05-28T10:30:00+00:00","endDate":"2008-05-28T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Bengaluru","address":{"@type":"PostalAddress","addressLocality":"M Chinnaswamy Stadium, Bangalore, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24"></div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-rajasthan-royals-56th-match-336019/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">56th match (N) </span>•&nbsp;Mohali, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">221/3</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:222) </span><strong class="">180/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="Kings XI won by 41 runs"><span>Kings XI won by 41 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-rajasthan-royals-56th-match-336019/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KXIP vs RR, 56th match, Indian Premier League","description":"Kings XI vs RR","startDate":"2008-05-28T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KXIP vs RR, 56th match, Indian Premier League","description":"Kings XI vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/kings-xi-punjab-vs-rajasthan-royals-56th-match-336019/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Kings XI"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-05-28T14:30:00+00:00","endDate":"2008-05-28T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mohali","address":{"@type":"PostalAddress","addressLocality":"Punjab Cricket Association Stadium, Mohali, Chandigarh, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Fri, 30 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-rajasthan-royals-1st-semi-final-336038/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">1st Semi-Final (N) </span>•&nbsp;Wankhede, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">192/9</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Delhi Daredevils"><img width="20" height="20" alt="Delhi Daredevils Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313422.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Delhi Daredevils</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(16.1/20 ov, T:193) </span><strong class="">87</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 105 runs"><span>RR won by 105 runs</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-rajasthan-royals-1st-semi-final-336038/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"RR vs DC, 1st Semi-Final, Indian Premier League","description":"RR vs Daredevils","startDate":"2008-05-30T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"RR vs DC, 1st Semi-Final, Indian Premier League","description":"RR vs Daredevils","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/delhi-daredevils-vs-rajasthan-royals-1st-semi-final-336038/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"RR"},{"@type":"SportsTeam","name":"Daredevils"}],"startDate":"2008-05-30T14:30:00+00:00","endDate":"2008-05-30T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mumbai","address":{"@type":"PostalAddress","addressLocality":"Wankhede Stadium, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sat, 31 May '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kings-xi-punjab-2nd-semi-final-336039/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">2nd Semi-Final (N) </span>•&nbsp;Wankhede, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Kings XI Punjab"><img width="20" height="20" alt="Kings XI Punjab Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/317000/317003.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Kings XI Punjab</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">112/8</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(14.5/20 ov, T:113) </span><strong class="">116/1</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="CSK won by 9 wickets (with 31 balls remaining)"><span>CSK won by 9 wickets (with 31 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kings-xi-punjab-2nd-semi-final-336039/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"KXIP vs CSK, 2nd Semi-Final, Indian Premier League","description":"Kings XI vs CSK","startDate":"2008-05-31T14:30:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"KXIP vs CSK, 2nd Semi-Final, Indian Premier League","description":"Kings XI vs CSK","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-kings-xi-punjab-2nd-semi-final-336039/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"Kings XI"},{"@type":"SportsTeam","name":"CSK"}],"startDate":"2008-05-31T14:30:00+00:00","endDate":"2008-05-31T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Mumbai","address":{"@type":"PostalAddress","addressLocality":"Wankhede Stadium, Mumbai, India"}}}}</script></div></div><div class="ds-p-4 hover:ds-bg-ui-fill-translucent ds-border-t ds-border-line ds-bg-ui-fill-translucent-hover"><div class="ds-flex"><div class="ds-text-compact-xs ds-font-bold ds-w-24">Sun, 01 Jun '08</div><div class="ds-grow ds-px-4 ds-border-r ds-border-line-default-translucent"><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-rajasthan-royals-final-336040/full-scorecard" class="ds-no-tap-higlight"><div class="ds-text-compact-xxs"><div class=""><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class="ds-flex ds-items-center"><span class=""><span class="ds-text-tight-s ds-font-bold ds-uppercase ds-leading-5">RESULT</span>&nbsp;•&nbsp;</span><div class="ds-text-tight-s ds-font-regular ds-truncate ds-text-typo-mid3"><span class="ds-text-tight-s ds-font-medium ds-text-typo">Final (N) </span>•&nbsp;DY Patil, <a href="/series/indian-premier-league-2007-08-313494" title="IPL" class="ds-inline-flex ds-items-start ds-leading-none !ds-inline"><span class="ds-text-tight-s ds-font-regular ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block !ds-inline">Indian Premier League</span></a></div></span></div></div><div class=""><div class="ds-flex ds-flex-col ds-mt-2 ds-mb-2"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-opacity-50 ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Chennai Super Kings"><img width="20" height="20" alt="Chennai Super Kings Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313421.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Chennai Super Kings</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5"></span><strong class="">163/5</strong></div></div><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo ds-my-1"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Rajasthan Royals"><img width="20" height="20" alt="Rajasthan Royals Flag" class="ds-mr-2" src="https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_80/lsci/db/PICTURES/CMS/313400/313423.logo.png" style="width: 20px; height: 20px;"><p class="ds-text-tight-m ds-font-bold ds-capitalize ds-truncate">Rajasthan Royals</p></div><div class="ds-text-compact-s ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-xs ds-mr-0.5">(20 ov, T:164) </span><strong class="">164/7</strong></div></div></div></div><p class="ds-text-tight-s ds-font-medium ds-line-clamp-2 ds-text-typo" title="RR won by 3 wickets (with 0 balls remaining)"><span>RR won by 3 wickets (with 0 balls remaining)</span></p></div></div></a><div class="ds-text-compact-xxs"><div class=""><span class="ds-inline-flex ds-items-center"><img width="44" height="12" alt="Bet 365 Logo" src="https://wassets.hscicdn.com/static/images/bet365-logo.svg" style="width: 44px; height: 12px;"><span class="ds-text-tight-s ds-font-regular ds-ml-2">In-play betting with bet365.</span></span><span class="ds-ml-4 ds-leading-3"><a href="https://www.bet365.com/olp/open-account?affiliate=365_728177" target="_blank" rel="noopener noreferrer" class="ds-inline-flex ds-items-center ds-text-typo-primary ds-leading-3"><span class="ds-text-tight-s ds-font-bold">Bet Now</span>&nbsp;<i class="icon-launch-outlined ds-text-icon-primary" style="font-size: 16px;"></i></a></span></div></div></div><div class="ds-px-4 ds-self-center ds-w-28"><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-rajasthan-royals-final-336040/match-report" title="Report" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Report</span></a></div><div><a href="/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-rajasthan-royals-final-336040/match-photo" title="Photos" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-compact-xs ds-text-typo hover:ds-underline hover:ds-decoration-ui-stroke ds-block">Photos</span></a></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"BroadcastEvent","name":"CSK vs RR, Final, Indian Premier League","description":"CSK vs RR","startDate":"2008-06-01T14:45:00+00:00","broadcastOfEvent":{"@type":"SportsEvent","name":"CSK vs RR, Final, Indian Premier League","description":"CSK vs RR","url":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494/chennai-super-kings-vs-rajasthan-royals-final-336040/live-cricket-score","competitor":[{"@type":"SportsTeam","name":"CSK"},{"@type":"SportsTeam","name":"RR"}],"startDate":"2008-06-01T14:45:00+00:00","endDate":"2008-06-01T00:00:00+00:00","eventAttendanceMode":"offline","eventStatus":"RESULT","organizer":{"name":"Indian Premier League","URL":"https://www.espncricinfo.com/series/indian-premier-league-2007-08-313494"},"performer":"cricketer","location":{"@type":"City","name":"Navi Mumbai","address":{"@type":"PostalAddress","addressLocality":"Dr DY Patil Sports Academy, Mumbai, India"}}}}</script></div></div></div></div>
